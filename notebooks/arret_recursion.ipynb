# %%
def fonction(a):
    return a*fonction(a-1)

# %%
fonction(4)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-3-c55837a7ba98> in <module>
# ----> 1 fonction(4)
#
# <ipython-input-2-9a91054b916a> in fonction(a)
#       1 def fonction(a):
# ----> 2     return a*fonction(a-1)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-2-9a91054b916a> in fonction(a)
#       1 def fonction(a):
# ----> 2     return a*fonction(a-1)
#
# RecursionError: maximum recursion depth exceeded

# %% [markdown]
# 1) Le programme s'arrête avant la fin car il y a trop de recursion de faites.
#
# En effet, il n'y a pas de condition d'arrêt dans la fonction

# %%
def fonction(a):
    if a==0:
        return 1
    else:
        return a*fonction(a-1)

# %%
fonction(4)
# Out:
# 24

# %% [markdown]
# 2) b) Elle retourne un résultat uniquement pour des valeurs de a>=0

# %%
fonction(-2)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-6-3917766331dd> in <module>
# ----> 1 fonction(-2)
#
# <ipython-input-4-5b51553b07ae> in fonction(a)
#       3         return 1
#       4     else:
# ----> 5         return a*fonction(a-1)
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-4-5b51553b07ae> in fonction(a)
#       3         return 1
#       4     else:
# ----> 5         return a*fonction(a-1)
#
# RecursionError: maximum recursion depth exceeded in comparison

# %% [markdown]
# 2) c) Il ne faut pas oublier dans une fonction récursive d'avoir une condition d'arrêt à la récursion.
